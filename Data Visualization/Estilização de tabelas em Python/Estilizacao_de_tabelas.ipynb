# %% [markdown]
# Nós trabalhamos com dados em uma grande loja de departamentos online e nos foi repassado um conjunto de dados referente a um relatório de vendas dos anos de 2016 a 2019. A partir deste relatório, temos o objetivo de criar visualizações para vários setores dessa loja de departamento a fim de conseguirmos transmitir essas informações.
#
# Para construirmos essas visualizações e passar essas informações, primeiro precisamos preparar nossos dados. Então, vamos começar!

# %% [markdown]
# # Coleta e preparação de dados

# %% [markdown]
# ## Bibliotecas e Configuracções

# %%
import pandas as pd
import numpy as np

# %%
print(pd.__version__)
print(np.__version__)
# Out:
# 2.0.3
# 1.25.2

# %% [markdown]
# ## Base de dados

# %%
path_data = './datasets/relatorio_vendas.csv'

df_vendas = pd.read_csv(path_data)
df_vendas.head()
# Out:
#   data_pedido      modo_envio       nome_cliente segmento_cliente  \
# 0  2018-11-09       Econômica    Thiago Silveira              B2C
# 1  2018-11-09       Econômica    Thiago Silveira              B2C
# 2  2018-06-13       Econômica      Giovanna Lima              B2B
# 3  2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
# 4  2017-10-12  Entrega padrão  Ana Júlia da Cruz              B2C
#
#            cidade          estado   regiao             departamento  \
# 0  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 1  Ribeirão Preto       São Paulo  Sudeste  Materiais de construção
# 2  Rio de Janeiro  Rio de Janeiro  Sudeste  Jardinagem e paisagismo
# 3   Foz do Iguaçu          Paraná      Sul  Materiais de construção
# 4   Foz do Iguaçu          Paraná      Sul  Jardinagem e paisagismo
#
#                 tipo_produto   vendas  quantidade    lucro
# 0               encanamentos   890.66           2   142.51
# 1                ferramentas  2488.60           3   746.58
# 2                   sementes    49.71           2    23.36
# 3  materiais de revestimento  3255.76           5 -1302.31
# 4                      vasos    76.05           2     8.56

# %%
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_pedido       8940 non-null   object
#  1   modo_envio        8940 non-null   object
#  2   nome_cliente      8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   cidade            8940 non-null   object
#  5   estado            8940 non-null   object
#  6   regiao            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_produto      8940 non-null   object
#  9   vendas            8940 non-null   float64
#  10  quantidade        8940 non-null   int64
#  11  lucro             8940 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 838.2+ KB

# %%
df_vendas['data_pedido'] = pd.to_datetime(df_vendas['data_pedido'])

# %%
df_vendas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8940 entries, 0 to 8939
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_pedido       8940 non-null   datetime64[ns]
#  1   modo_envio        8940 non-null   object
#  2   nome_cliente      8940 non-null   object
#  3   segmento_cliente  8940 non-null   object
#  4   cidade            8940 non-null   object
#  5   estado            8940 non-null   object
#  6   regiao            8940 non-null   object
#  7   departamento      8940 non-null   object
#  8   tipo_produto      8940 non-null   object
#  9   vendas            8940 non-null   float64
#  10  quantidade        8940 non-null   int64
#  11  lucro             8940 non-null   float64
# dtypes: datetime64[ns](1), float64(2), int64(1), object(8)
# memory usage: 838.2+ KB

# %% [markdown]
# # Missão 1: Time de vendas
#
# Precisamos construir uma visualização para indicar os **10 maiores clientes por total de venda**.
#
# Com isso, a equipe de vendas pode pensar em estratégias para manter esses clientes comprando em nossa loja.

# %%
df_clientes_vendas = df_vendas[['nome_cliente', 'vendas']].groupby(by='nome_cliente').sum('vendas')
df_clientes_vendas = df_clientes_vendas.sort_values('vendas', ascending=False)
df_clientes_vendas_rank = df_clientes_vendas.head(10).reset_index()
df_clientes_vendas_rank.index = range(1, len(df_clientes_vendas_rank )+ 1) #pd.RangeIndex(start=1, stop=len(df_clientes_vendas_rank) + 1)
df_clientes_vendas_rank.index.name = 'Rank'
df_clientes_vendas_rank
# Out:
#                nome_cliente    vendas
# Rank
# 1       Maria Luiza Almeida  64777.54
# 2           Ana Julia Pinto  51398.95
# 3               Ryan Farias  48178.94
# 4            Heitor da Mata  47610.85
# 5     Maria Clara Gonçalves  46946.42
# 6            Raquel Freitas  44826.26
# 7                Davi Ramos  43769.21
# 8               Amanda Melo  42354.27
# 9            Alexia Ribeiro  41238.84
# 10           Calebe Ribeiro  41056.70

# %%
df_clientes_vendas_rank.columns = ['Clientes', 'Vendas']

# %%
df_clientes_vendas_rank
# Out:
#                    Clientes    Vendas
# Rank
# 1       Maria Luiza Almeida  64777.54
# 2           Ana Julia Pinto  51398.95
# 3               Ryan Farias  48178.94
# 4            Heitor da Mata  47610.85
# 5     Maria Clara Gonçalves  46946.42
# 6            Raquel Freitas  44826.26
# 7                Davi Ramos  43769.21
# 8               Amanda Melo  42354.27
# 9            Alexia Ribeiro  41238.84
# 10           Calebe Ribeiro  41056.70

# %%
s = df_clientes_vendas_rank.style

s.format({'Vendas': 'R$ {:,.2f}'})
# Out:
# <style type="text/css">
# </style>
# <table id="T_bc140">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc140_level0_col0" class="col_heading level0 col0" >Clientes</th>
#       <th id="T_bc140_level0_col1" class="col_heading level0 col1" >Vendas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc140_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_bc140_row0_col0" class="data row0 col0" >Maria Luiza Almeida</td>
#       <td id="T_bc140_row0_col1" class="data row0 col1" >R$ 64,777.54</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_bc140_row1_col0" class="data row1 col0" >Ana Julia Pinto</td>
#       <td id="T_bc140_row1_col1" class="data row1 col1" >R$ 51,398.95</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_bc140_row2_col0" class="data row2 col0" >Ryan Farias</td>
#       <td id="T_bc140_row2_col1" class="data row2 col1" >R$ 48,178.94</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_bc140_row3_col0" class="data row3 col0" >Heitor da Mata</td>
#       <td id="T_bc140_row3_col1" class="data row3 col1" >R$ 47,610.85</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_bc140_row4_col0" class="data row4 col0" >Maria Clara Gonçalves</td>
#       <td id="T_bc140_row4_col1" class="data row4 col1" >R$ 46,946.42</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_bc140_row5_col0" class="data row5 col0" >Raquel Freitas</td>
#       <td id="T_bc140_row5_col1" class="data row5 col1" >R$ 44,826.26</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_bc140_row6_col0" class="data row6 col0" >Davi Ramos</td>
#       <td id="T_bc140_row6_col1" class="data row6 col1" >R$ 43,769.21</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_bc140_row7_col0" class="data row7 col0" >Amanda Melo</td>
#       <td id="T_bc140_row7_col1" class="data row7 col1" >R$ 42,354.27</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_bc140_row8_col0" class="data row8 col0" >Alexia Ribeiro</td>
#       <td id="T_bc140_row8_col1" class="data row8 col1" >R$ 41,238.84</td>
#     </tr>
#     <tr>
#       <th id="T_bc140_level0_row9" class="row_heading level0 row9" >10</th>
#       <td id="T_bc140_row9_col0" class="data row9 col0" >Calebe Ribeiro</td>
#       <td id="T_bc140_row9_col1" class="data row9 col1" >R$ 41,056.70</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Execícios

# %%
# Dados da tabela
data = {'Porcentagem de Vendas': [10.5, 15.2, 20.6, 8.3, 12.1, 9.8, 17.9, 5.6],
    'Tipo de Ventilador': ['Ventilador de mesa', 'Ventilador de pedestal',
                           'Ventilador de teto', 'Ventilador de parede',
                           'Ventilador de torre', 'Ventilador de janela',
                           'Ventilador de coluna', 'Ventilador de exaustão']}

# Criando o DataFrame
df = pd.DataFrame(data)
df = df.set_index('Tipo de Ventilador')
df
# Out:
#                         Porcentagem de Vendas
# Tipo de Ventilador
# Ventilador de mesa                       10.5
# Ventilador de pedestal                   15.2
# Ventilador de teto                       20.6
# Ventilador de parede                      8.3
# Ventilador de torre                      12.1
# Ventilador de janela                      9.8
# Ventilador de coluna                     17.9
# Ventilador de exaustão                    5.6

# %%
s2 = df.style
s2
# Out:
# <style type="text/css">
# </style>
# <table id="T_13df1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13df1_level0_col0" class="col_heading level0 col0" >Porcentagem de Vendas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Ventilador</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13df1_level0_row0" class="row_heading level0 row0" >Ventilador de mesa</th>
#       <td id="T_13df1_row0_col0" class="data row0 col0" >10.500000</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row1" class="row_heading level0 row1" >Ventilador de pedestal</th>
#       <td id="T_13df1_row1_col0" class="data row1 col0" >15.200000</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row2" class="row_heading level0 row2" >Ventilador de teto</th>
#       <td id="T_13df1_row2_col0" class="data row2 col0" >20.600000</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row3" class="row_heading level0 row3" >Ventilador de parede</th>
#       <td id="T_13df1_row3_col0" class="data row3 col0" >8.300000</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row4" class="row_heading level0 row4" >Ventilador de torre</th>
#       <td id="T_13df1_row4_col0" class="data row4 col0" >12.100000</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row5" class="row_heading level0 row5" >Ventilador de janela</th>
#       <td id="T_13df1_row5_col0" class="data row5 col0" >9.800000</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row6" class="row_heading level0 row6" >Ventilador de coluna</th>
#       <td id="T_13df1_row6_col0" class="data row6 col0" >17.900000</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row7" class="row_heading level0 row7" >Ventilador de exaustão</th>
#       <td id="T_13df1_row7_col0" class="data row7 col0" >5.600000</td>
#     </tr>
#   </tbody>
# </table>

# %%
s2.format('{:.2f} %')
# Out:
# <style type="text/css">
# </style>
# <table id="T_13df1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_13df1_level0_col0" class="col_heading level0 col0" >Porcentagem de Vendas</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Tipo de Ventilador</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_13df1_level0_row0" class="row_heading level0 row0" >Ventilador de mesa</th>
#       <td id="T_13df1_row0_col0" class="data row0 col0" >10.50 %</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row1" class="row_heading level0 row1" >Ventilador de pedestal</th>
#       <td id="T_13df1_row1_col0" class="data row1 col0" >15.20 %</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row2" class="row_heading level0 row2" >Ventilador de teto</th>
#       <td id="T_13df1_row2_col0" class="data row2 col0" >20.60 %</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row3" class="row_heading level0 row3" >Ventilador de parede</th>
#       <td id="T_13df1_row3_col0" class="data row3 col0" >8.30 %</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row4" class="row_heading level0 row4" >Ventilador de torre</th>
#       <td id="T_13df1_row4_col0" class="data row4 col0" >12.10 %</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row5" class="row_heading level0 row5" >Ventilador de janela</th>
#       <td id="T_13df1_row5_col0" class="data row5 col0" >9.80 %</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row6" class="row_heading level0 row6" >Ventilador de coluna</th>
#       <td id="T_13df1_row6_col0" class="data row6 col0" >17.90 %</td>
#     </tr>
#     <tr>
#       <th id="T_13df1_level0_row7" class="row_heading level0 row7" >Ventilador de exaustão</th>
#       <td id="T_13df1_row7_col0" class="data row7 col0" >5.60 %</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Exercício 2
#
# * O primeiro desafio é construir uma visualização que permita identificar quais países mais solicitaram produtos por pedidos para que assim possa ser feito um estudo quanto a distribuição e logística de produtos.

# %%
url = 'https://caelum-online-public.s3.amazonaws.com/3056-data-visualization/loja_livro_filmes.csv'

# %%
df = pd.read_csv(url)
df.head(3)
# Out:
#         pais  id_cliente data_pedido data_chegada tipo_compra  numero_pedido  \
# 0  Argentina   111962928  2002-02-15   2002-03-10      Normal       98091426
# 1  Argentina   145148150  2004-11-05   2004-11-26      Normal       98087803
# 2  Argentina   194622983  2014-09-14   2014-09-28      Normal       98072296
#
#    tamanho_pacote  unidades  custo_empacotamento  custo_envio tipo_desconto  \
# 0  Pacote pequeno         1                  3.0         5.99  Sem desconto
# 1  Pacote pequeno         3                  1.0         6.99  Sem desconto
# 2  Pacote pequeno         1                  3.0         6.99  Sem desconto
#
#   categoria  tipo_consumo tipo_cliente  custo_produto
# 0   BlueRay  Alto Consumo          B2C           8.99
# 1   BlueRay  Alto Consumo          B2C           7.99
# 2   BlueRay  Alto Consumo          B2C           9.99

# %%
df_unidades_pais = df[['pais', 'unidades']].groupby('pais').sum().sort_values('unidades', ascending=False)
df_unidades_pais = df_unidades_pais.reset_index()
df_unidades_pais.index = range(1, len(df_unidades_pais) +1)
df_unidades_pais.index.name = 'Rank'
df_unidades_pais
# Out:
#            pais  unidades
# Rank
# 1     Argentina      5591
# 2       Equador      5566
# 3      Paraguai      5564
# 4          Peru      5550
# 5     Venezuela      5529
# 6      Colômbia      5504
# 7        Brasil      5473
# 8       Uruguai      5377
# 9         Chile      5304

# %%
df3 = df_unidades_pais.style

df3
# Out:
# <style type="text/css">
# </style>
# <table id="T_68c02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68c02_level0_col0" class="col_heading level0 col0" >pais</th>
#       <th id="T_68c02_level0_col1" class="col_heading level0 col1" >unidades</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68c02_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_68c02_row0_col0" class="data row0 col0" >Argentina</td>
#       <td id="T_68c02_row0_col1" class="data row0 col1" >5591</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_68c02_row1_col0" class="data row1 col0" >Equador</td>
#       <td id="T_68c02_row1_col1" class="data row1 col1" >5566</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_68c02_row2_col0" class="data row2 col0" >Paraguai</td>
#       <td id="T_68c02_row2_col1" class="data row2 col1" >5564</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_68c02_row3_col0" class="data row3 col0" >Peru</td>
#       <td id="T_68c02_row3_col1" class="data row3 col1" >5550</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_68c02_row4_col0" class="data row4 col0" >Venezuela</td>
#       <td id="T_68c02_row4_col1" class="data row4 col1" >5529</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_68c02_row5_col0" class="data row5 col0" >Colômbia</td>
#       <td id="T_68c02_row5_col1" class="data row5 col1" >5504</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_68c02_row6_col0" class="data row6 col0" >Brasil</td>
#       <td id="T_68c02_row6_col1" class="data row6 col1" >5473</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_68c02_row7_col0" class="data row7 col0" >Uruguai</td>
#       <td id="T_68c02_row7_col1" class="data row7 col1" >5377</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_68c02_row8_col0" class="data row8 col0" >Chile</td>
#       <td id="T_68c02_row8_col1" class="data row8 col1" >5304</td>
#     </tr>
#   </tbody>
# </table>

# %%
df3 = df3.format({'unidades' : 'unidades pedidas: {}'})
df3
# Out:
# <style type="text/css">
# </style>
# <table id="T_68c02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_68c02_level0_col0" class="col_heading level0 col0" >pais</th>
#       <th id="T_68c02_level0_col1" class="col_heading level0 col1" >unidades</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Rank</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68c02_level0_row0" class="row_heading level0 row0" >1</th>
#       <td id="T_68c02_row0_col0" class="data row0 col0" >Argentina</td>
#       <td id="T_68c02_row0_col1" class="data row0 col1" >unidades pedidas: 5591</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row1" class="row_heading level0 row1" >2</th>
#       <td id="T_68c02_row1_col0" class="data row1 col0" >Equador</td>
#       <td id="T_68c02_row1_col1" class="data row1 col1" >unidades pedidas: 5566</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row2" class="row_heading level0 row2" >3</th>
#       <td id="T_68c02_row2_col0" class="data row2 col0" >Paraguai</td>
#       <td id="T_68c02_row2_col1" class="data row2 col1" >unidades pedidas: 5564</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row3" class="row_heading level0 row3" >4</th>
#       <td id="T_68c02_row3_col0" class="data row3 col0" >Peru</td>
#       <td id="T_68c02_row3_col1" class="data row3 col1" >unidades pedidas: 5550</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row4" class="row_heading level0 row4" >5</th>
#       <td id="T_68c02_row4_col0" class="data row4 col0" >Venezuela</td>
#       <td id="T_68c02_row4_col1" class="data row4 col1" >unidades pedidas: 5529</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row5" class="row_heading level0 row5" >6</th>
#       <td id="T_68c02_row5_col0" class="data row5 col0" >Colômbia</td>
#       <td id="T_68c02_row5_col1" class="data row5 col1" >unidades pedidas: 5504</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row6" class="row_heading level0 row6" >7</th>
#       <td id="T_68c02_row6_col0" class="data row6 col0" >Brasil</td>
#       <td id="T_68c02_row6_col1" class="data row6 col1" >unidades pedidas: 5473</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row7" class="row_heading level0 row7" >8</th>
#       <td id="T_68c02_row7_col0" class="data row7 col0" >Uruguai</td>
#       <td id="T_68c02_row7_col1" class="data row7 col1" >unidades pedidas: 5377</td>
#     </tr>
#     <tr>
#       <th id="T_68c02_level0_row8" class="row_heading level0 row8" >9</th>
#       <td id="T_68c02_row8_col0" class="data row8 col0" >Chile</td>
#       <td id="T_68c02_row8_col1" class="data row8 col1" >unidades pedidas: 5304</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Missão 2: Time comercial
#
# Precisamos construir uma visualização que permita associar o **total ganho em vendas e o total lucrado por tipo de produto**.
#
# Isso vai permitir que o time comercial possa focar em estratégias para alavancar as rendas que ganham com cada tipo de produto vendido na loja.

# %%
df_venda_lucro = df_vendas[['tipo_produto','vendas', 'lucro']].groupby('tipo_produto').sum()
df_venda_lucro = df_venda_lucro.sort_values(by='lucro', ascending=False)

# %%
estilo_produto = df_venda_lucro.style
estilo_produto
# Out:
# <style type="text/css">
# </style>
# <table id="T_0d19d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d19d_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_0d19d_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo_produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d19d_level0_row0" class="row_heading level0 row0" >peças de reposição</th>
#       <td id="T_0d19d_row0_col0" class="data row0 col0" >486907.880000</td>
#       <td id="T_0d19d_row0_col1" class="data row0 col1" >182297.320000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row1" class="row_heading level0 row1" >pneus</th>
#       <td id="T_0d19d_row1_col0" class="data row1 col0" >1022430.500000</td>
#       <td id="T_0d19d_row1_col1" class="data row1 col1" >134923.090000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row2" class="row_heading level0 row2" >ferramentas automotivas</th>
#       <td id="T_0d19d_row2_col0" class="data row2 col0" >502109.330000</td>
#       <td id="T_0d19d_row2_col1" class="data row2 col1" >126660.540000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row3" class="row_heading level0 row3" >pesticidas</th>
#       <td id="T_0d19d_row3_col0" class="data row3 col0" >244958.410000</td>
#       <td id="T_0d19d_row3_col1" class="data row3 col1" >106688.030000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row4" class="row_heading level0 row4" >ferramentas de jardinagem</th>
#       <td id="T_0d19d_row4_col0" class="data row4 col0" >648880.470000</td>
#       <td id="T_0d19d_row4_col1" class="data row4 col1" >106408.800000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row5" class="row_heading level0 row5" >ferramentas</th>
#       <td id="T_0d19d_row5_col0" class="data row5 col0" >995159.430000</td>
#       <td id="T_0d19d_row5_col1" class="data row5 col1" >82042.910000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row6" class="row_heading level0 row6" >vasos</th>
#       <td id="T_0d19d_row6_col0" class="data row6 col0" >696045.390000</td>
#       <td id="T_0d19d_row6_col1" class="data row6 col1" >67887.280000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row7" class="row_heading level0 row7" >mobiliário de exterior</th>
#       <td id="T_0d19d_row7_col0" class="data row7 col0" >328932.370000</td>
#       <td id="T_0d19d_row7_col1" class="data row7 col1" >53569.570000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row8" class="row_heading level0 row8" >iluminação</th>
#       <td id="T_0d19d_row8_col0" class="data row8 col0" >275229.820000</td>
#       <td id="T_0d19d_row8_col1" class="data row8 col1" >40531.090000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row9" class="row_heading level0 row9" >fertilizantes</th>
#       <td id="T_0d19d_row9_col0" class="data row9 col0" >53144.550000</td>
#       <td id="T_0d19d_row9_col1" class="data row9 col1" >22509.860000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row10" class="row_heading level0 row10" >decoração de jardim</th>
#       <td id="T_0d19d_row10_col0" class="data row10 col0" >82680.870000</td>
#       <td id="T_0d19d_row10_col1" class="data row10 col1" >19880.860000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row11" class="row_heading level0 row11" >sementes</th>
#       <td id="T_0d19d_row11_col0" class="data row11 col0" >39980.490000</td>
#       <td id="T_0d19d_row11_col1" class="data row11 col1" >17730.060000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row12" class="row_heading level0 row12" >equipamentos de limpeza</th>
#       <td id="T_0d19d_row12_col0" class="data row12 col0" >542304.550000</td>
#       <td id="T_0d19d_row12_col1" class="data row12 col1" >17448.300000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row13" class="row_heading level0 row13" >mudas</th>
#       <td id="T_0d19d_row13_col0" class="data row13 col0" >8811.690000</td>
#       <td id="T_0d19d_row13_col1" class="data row13 col1" >2762.880000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row14" class="row_heading level0 row14" >materiais de paisagismo</th>
#       <td id="T_0d19d_row14_col0" class="data row14 col0" >150552.800000</td>
#       <td id="T_0d19d_row14_col1" class="data row14 col1" >-3823.670000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row15" class="row_heading level0 row15" >encanamentos</th>
#       <td id="T_0d19d_row15_col0" class="data row15 col0" >373224.390000</td>
#       <td id="T_0d19d_row15_col1" class="data row15 col1" >-11243.390000</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row16" class="row_heading level0 row16" >materiais de revestimento</th>
#       <td id="T_0d19d_row16_col0" class="data row16 col0" >629656.410000</td>
#       <td id="T_0d19d_row16_col1" class="data row16 col1" >-57737.230000</td>
#     </tr>
#   </tbody>
# </table>

# %%
estilo_produto = estilo_produto.format('R$ {:,.2f}').highlight_max(color='lightgreen').highlight_min(color='#F16165')
estilo_produto
# Out:
# <style type="text/css">
# #T_0d19d_row0_col1, #T_0d19d_row1_col0 {
#   background-color: red;
#   background-color: blue;
#   background-color: bluelight;
#   background-color: blue_light;
#   background-color: light_green;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
# }
# #T_0d19d_row13_col0, #T_0d19d_row16_col1 {
#   background-color: lightred;
#   background-color: #F16165;
#   background-color: #F16165;
#   background-color: #F16165;
#   background-color: #F16165;
#   background-color: #F16165;
# }
# </style>
# <table id="T_0d19d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d19d_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_0d19d_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo_produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d19d_level0_row0" class="row_heading level0 row0" >peças de reposição</th>
#       <td id="T_0d19d_row0_col0" class="data row0 col0" >R$ 486,907.88</td>
#       <td id="T_0d19d_row0_col1" class="data row0 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row1" class="row_heading level0 row1" >pneus</th>
#       <td id="T_0d19d_row1_col0" class="data row1 col0" >R$ 1,022,430.50</td>
#       <td id="T_0d19d_row1_col1" class="data row1 col1" >R$ 134,923.09</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row2" class="row_heading level0 row2" >ferramentas automotivas</th>
#       <td id="T_0d19d_row2_col0" class="data row2 col0" >R$ 502,109.33</td>
#       <td id="T_0d19d_row2_col1" class="data row2 col1" >R$ 126,660.54</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row3" class="row_heading level0 row3" >pesticidas</th>
#       <td id="T_0d19d_row3_col0" class="data row3 col0" >R$ 244,958.41</td>
#       <td id="T_0d19d_row3_col1" class="data row3 col1" >R$ 106,688.03</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row4" class="row_heading level0 row4" >ferramentas de jardinagem</th>
#       <td id="T_0d19d_row4_col0" class="data row4 col0" >R$ 648,880.47</td>
#       <td id="T_0d19d_row4_col1" class="data row4 col1" >R$ 106,408.80</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row5" class="row_heading level0 row5" >ferramentas</th>
#       <td id="T_0d19d_row5_col0" class="data row5 col0" >R$ 995,159.43</td>
#       <td id="T_0d19d_row5_col1" class="data row5 col1" >R$ 82,042.91</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row6" class="row_heading level0 row6" >vasos</th>
#       <td id="T_0d19d_row6_col0" class="data row6 col0" >R$ 696,045.39</td>
#       <td id="T_0d19d_row6_col1" class="data row6 col1" >R$ 67,887.28</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row7" class="row_heading level0 row7" >mobiliário de exterior</th>
#       <td id="T_0d19d_row7_col0" class="data row7 col0" >R$ 328,932.37</td>
#       <td id="T_0d19d_row7_col1" class="data row7 col1" >R$ 53,569.57</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row8" class="row_heading level0 row8" >iluminação</th>
#       <td id="T_0d19d_row8_col0" class="data row8 col0" >R$ 275,229.82</td>
#       <td id="T_0d19d_row8_col1" class="data row8 col1" >R$ 40,531.09</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row9" class="row_heading level0 row9" >fertilizantes</th>
#       <td id="T_0d19d_row9_col0" class="data row9 col0" >R$ 53,144.55</td>
#       <td id="T_0d19d_row9_col1" class="data row9 col1" >R$ 22,509.86</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_
</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Exercícios

# %%
# Dados da tabela
dados = {'Jogadoras': ['Lana', 'Maria', 'Paula', 'Ana', 'Sandy'],
         'Pontuação': [56, 72, 49, 85, 68]}

# Criando o DataFrame
df = pd.DataFrame(dados)
df = df.set_index('Jogadoras').sort_values('Pontuação', ascending=False)
df
# Out:
#            Pontuação
# Jogadoras
# Ana               85
# Maria             72
# Sandy             68
# Lana              56
# Paula             49

# %%
df4 = df.style.background_gradient(cmap='Greens')
df4
# Out:
# <style type="text/css">
# #T_e3818_row0_col0 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_e3818_row1_col0 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_e3818_row2_col0 {
#   background-color: #68be70;
#   color: #000000;
# }
# #T_e3818_row3_col0 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_e3818_row4_col0 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_e3818">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e3818_level0_col0" class="col_heading level0 col0" >Pontuação</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Jogadoras</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e3818_level0_row0" class="row_heading level0 row0" >Ana</th>
#       <td id="T_e3818_row0_col0" class="data row0 col0" >85</td>
#     </tr>
#     <tr>
#       <th id="T_e3818_level0_row1" class="row_heading level0 row1" >Maria</th>
#       <td id="T_e3818_row1_col0" class="data row1 col0" >72</td>
#     </tr>
#     <tr>
#       <th id="T_e3818_level0_row2" class="row_heading level0 row2" >Sandy</th>
#       <td id="T_e3818_row2_col0" class="data row2 col0" >68</td>
#     </tr>
#     <tr>
#       <th id="T_e3818_level0_row3" class="row_heading level0 row3" >Lana</th>
#       <td id="T_e3818_row3_col0" class="data row3 col0" >56</td>
#     </tr>
#     <tr>
#       <th id="T_e3818_level0_row4" class="row_heading level0 row4" >Paula</th>
#       <td id="T_e3818_row4_col0" class="data row4 col0" >49</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # -----------------------------------------------------------------------------------------------------

# %%
cabecalho = {
    'selector':'th',
    'props':'font-weight: bold; font-family: Arial; text-align: center; text-transform: capitalize;'
}

estilo_produto.set_table_styles([cabecalho], overwrite=False)
# Out:
# <style type="text/css">
# #T_0d19d th {
#   font-weight: bold;
#   font-family: Arial;
#   text-align: center;
#   text-transform: capitalize;
# }
# #T_0d19d_row0_col0 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# #T_0d19d_row0_col1, #T_0d19d_row1_col0 {
#   background-color: red;
#   background-color: blue;
#   background-color: bluelight;
#   background-color: blue_light;
#   background-color: light_green;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: lightgreen;
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_0d19d_row1_col1 {
#   background-color: #147e3a;
#   color: #f1f1f1;
# }
# #T_0d19d_row2_col0 {
#   background-color: #79c67a;
#   color: #000000;
# }
# #T_0d19d_row2_col1 {
#   background-color: #1e8741;
#   color: #f1f1f1;
# }
# #T_0d19d_row3_col0 {
#   background-color: #cbebc5;
#   color: #000000;
# }
# #T_0d19d_row3_col1, #T_0d19d_row4_col1 {
#   background-color: #329b51;
#   color: #f1f1f1;
# }
# #T_0d19d_row4_col0 {
#   background-color: #3fa95c;
#   color: #f1f1f1;
# }
# #T_0d19d_row5_col0 {
#   background-color: #004c1e;
#   color: #f1f1f1;
# }
# #T_0d19d_row5_col1 {
#   background-color: #52b365;
#   color: #f1f1f1;
# }
# #T_0d19d_row6_col0 {
#   background-color: #349d53;
#   color: #f1f1f1;
# }
# #T_0d19d_row6_col1 {
#   background-color: #6bc072;
#   color: #000000;
# }
# #T_0d19d_row7_col0, #T_0d19d_row11_col1, #T_0d19d_row12_col1 {
#   background-color: #b4e1ad;
#   color: #000000;
# }
# #T_0d19d_row7_col1 {
#   background-color: #81ca81;
#   color: #000000;
# }
# #T_0d19d_row8_col0 {
#   background-color: #c3e7bc;
#   color: #000000;
# }
# #T_0d19d_row8_col1 {
#   background-color: #95d391;
#   color: #000000;
# }
# #T_0d19d_row9_col0 {
#   background-color: #f1faee;
#   color: #000000;
# }
# #T_0d19d_row9_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_0d19d_row10_col0 {
#   background-color: #edf8e9;
#   color: #000000;
# }
# #T_0d19d_row10_col1 {
#   background-color: #b1e0ab;
#   color: #000000;
# }
# #T_0d19d_row11_col0 {
#   background-color: #f3faf0;
#   color: #000000;
# }
# #T_0d19d_row12_col0 {
#   background-color: #6abf71;
#   color: #000000;
# }
# #T_0d19d_row13_col0, #T_0d19d_row16_col1 {
#   background-color: lightred;
#   background-color: #F16165;
#   background-color: #F16165;
#   background-color: #F16165;
#   background-color: #F16165;
#   background-color: #F16165;
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_0d19d_row13_col1 {
#   background-color: #c7e9c0;
#   color: #000000;
# }
# #T_0d19d_row14_col0 {
#   background-color: #e2f4dd;
#   color: #000000;
# }
# #T_0d19d_row14_col1 {
#   background-color: #cdecc7;
#   color: #000000;
# }
# #T_0d19d_row15_col0 {
#   background-color: #a5db9f;
#   color: #000000;
# }
# #T_0d19d_row15_col1 {
#   background-color: #d5efcf;
#   color: #000000;
# }
# #T_0d19d_row16_col0 {
#   background-color: #46ae60;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_0d19d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0d19d_level0_col0" class="col_heading level0 col0" >vendas</th>
#       <th id="T_0d19d_level0_col1" class="col_heading level0 col1" >lucro</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >tipo_produto</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0d19d_level0_row0" class="row_heading level0 row0" >peças de reposição</th>
#       <td id="T_0d19d_row0_col0" class="data row0 col0" >R$ 486,907.88</td>
#       <td id="T_0d19d_row0_col1" class="data row0 col1" >R$ 182,297.32</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_
td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row15" class="row_heading level0 row15" >encanamentos</th>
#       <td id="T_0d19d_row15_col0" class="data row15 col0" >R$ 373,224.39</td>
#       <td id="T_0d19d_row15_col1" class="data row15 col1" >R$ -11,243.39</td>
#     </tr>
#     <tr>
#       <th id="T_0d19d_level0_row16" class="row_heading level0 row16" >materiais de revestimento</th>
#       <td id="T_0d19d_row16_col0" class="data row16 col0" >R$ 629,656.41</td>
#       <td id="T_0d19d_row16_col1" class="data row16 col1" >R$ -57,737.23</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Exercícios

# %%
url2 = 'https://caelum-online-public.s3.amazonaws.com/3056-data-visualization/loja_livro_filmes.csv'

# %%
df_loja_livro = pd.read_csv(url2)

# %%
df_loja_livro
# Out:
#             pais  id_cliente data_pedido data_chegada tipo_compra  \
# 0      Argentina   111962928  2002-02-15   2002-03-10      Normal
# 1      Argentina   145148150  2004-11-05   2004-11-26      Normal
# 2      Argentina   194622983  2014-09-14   2014-09-28      Normal
# 3      Argentina   220834258  2011-07-20   2011-07-30   Devolução
# 4      Argentina   220834258  2013-09-15   2017-02-15      Normal
# ...          ...         ...         ...          ...         ...
# 24885  Venezuela   890670789  2006-05-05   2006-05-18   Devolução
# 24886  Venezuela   892274535  2002-02-20   2002-03-08      Normal
# 24887  Venezuela   892274535  2015-01-26   2015-02-17      Normal
# 24888  Venezuela   898039697  2002-08-22   2002-09-06      Normal
# 24889  Venezuela   898039697  2009-05-27   2009-06-17      Normal
#
#        numero_pedido  tamanho_pacote  unidades  custo_empacotamento  \
# 0           98091426  Pacote pequeno         1                  3.0
# 1           98087803  Pacote pequeno         3                  1.0
# 2           98072296  Pacote pequeno         1                  3.0
# 3           98077986  Pacote pequeno         2                  1.0
# 4           98074234  Pacote pequeno         1                  2.0
# ...              ...             ...       ...                  ...
# 24885       98085835  Pacote pequeno         2                  1.0
# 24886       98091414  Pacote pequeno         1                  2.0
# 24887       98071516  Pacote pequeno         3                  3.0
# 24888       98090720  Pacote pequeno         2                  2.0
# 24889       98081676  Pacote pequeno         1                  1.0
#
#        custo_envio tipo_desconto categoria  tipo_consumo tipo_cliente  \
# 0             5.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 1             6.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 2             6.99  Sem desconto   BlueRay  Alto Consumo          B2C
# 3             3.86  Cyber Monday   BlueRay  Alto Consumo          B2B
# 4             4.88  Black Friday   BlueRay  Alto Consumo          B2B
# ...            ...           ...       ...           ...          ...
# 24885         6.99  Sem desconto     Livro  Alto Consumo          B2C
# 24886         6.25  Cyber Monday     Livro  Alto Consumo          B2B
# 24887         4.65  Sem desconto     Livro  Alto Consumo          B2B
# 24888         4.58  Sem desconto     Livro  Alto Consumo          B2B
# 24889         6.65  Sem desconto     Livro  Alto Consumo          B2B
#
#        custo_produto
# 0               8.99
# 1               7.99
# 2               9.99
# 3               4.86
# 4               6.88
# ...              ...
# 24885           7.99
# 24886           8.25
# 24887           7.65
# 24888           6.58
# 24889           7.65
#
# [24890 rows x 15 columns]

# %%
df_produto_custos = df_loja_livro[['categoria', 'custo_produto']].groupby(by='categoria')
df_produto_custos = df_produto_custos.sum().sort_values(by='custo_produto', ascending=True)
df_produto_custos.columns = ['Custo Produto']
df_produto_custos.index.name = 'Categoria'
df_produto_custos
# Out:
#            Custo Produto
# Categoria
# CD              10514.28
# BlueRay         14191.36
# Coleção         73128.59
# Livro           78213.80

# %%
df_produto_custos_style = df_produto_custos.style

# %%
df_produto_custos_style.format('R$ {:,.2f}').highlight_max(color='#F16165').highlight_min(color='lightgreen')
# Out:
# <style type="text/css">
# #T_ad71e_row0_col0 {
#   background-color: lightgreen;
# }
# #T_ad71e_row3_col0 {
#   background-color: #F16165;
# }
# </style>
# <table id="T_ad71e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ad71e_level0_col0" class="col_heading level0 col0" >Custo Produto</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Categoria</th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad71e_level0_row0" class="row_heading level0 row0" >CD</th>
#       <td id="T_ad71e_row0_col0" class="data row0 col0" >R$ 10,514.28</td>
#     </tr>
#     <tr>
#       <th id="T_ad71e_level0_row1" class="row_heading level0 row1" >BlueRay</th>
#       <td id="T_ad71e_row1_col0" class="data row1 col0" >R$ 14,191.36</td>
#     </tr>
#     <tr>
#       <th id="T_ad71e_level0_row2" class="row_heading level0 row2" >Coleção</th>
#       <td id="T_ad71e_row2_col0" class="data row2 col0" >R$ 73,128.59</td>
#     </tr>
#     <tr>
#       <th id="T_ad71e_level0_row3" class="row_heading level0 row3" >Livro</th>
#       <td id="T_ad71e_row3_col0" class="data row3 col0" >R$ 78,213.80</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # Missão 3: Time de logística
#
# Precisamos construir uma visualização que permita entender a **distribuição de pedidos por região do Brasil**.
#
# Isso vai permitir que o time logística entenda onde é mais interessante focar material e pessoas.

# %%
df_regiao = df_vendas[['regiao', 'quantidade']].groupby(by='regiao').count().sort_values('quantidade', ascending=False)
df_regiao.columns = ['Nº pedidos']
df_regiao.index.name = 'Regiao'

df_regiao
# Out:
#               Nº pedidos
# Regiao
# Sudeste             4470
# Nordeste            2075
# Centro-Oeste         983
# Norte                779
# Sul                  633

# %%
df_regiao['porcentagem'] = ((df_regiao['Nº pedidos'] / df_regiao['Nº pedidos'].sum()) * 100)

df_regiao
# Out:
#               Nº pedidos  porcentagem
# Regiao
# Sudeste             4470    50.000000
# Nordeste            2075    23.210291
# Centro-Oeste         983    10.995526
# Norte                779     8.713647
# Sul                  633     7.080537

# %% [markdown]
# # Missão 4: Time de logística
#
# Novamente o time de logística deseja repensar sua estrutura e organização de fornecimento de produtos e para isso, foi pensada em uma visualização que permita identificar padrão de **quantidade de produtos solicitados por mês por departamento**.

# %% [markdown]
# # Missão 5: Relatório de performance
#
# O relatório de performance é um documento muito importante para a empresa. Nele, todos que trabalham na loja podem entender como anda a empresa. Por conta disso, tabelas bem construídas são essenciais para mostrar os dados da melhor forma.
#
# Portanto, precisamos construir uma visualização que permita entender a **relação entre tipos de clientes e modo de envio de produtos de acordo com as vendas**. Com isso, será possível destacar no relatório qual o modo de envio e quais tipos de modo de envio mais geraram ganho em vendas.
